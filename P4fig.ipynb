# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('seaborn-darkgrid')

df= pd.read_csv("P4fig.csv")

ax=sns.lmplot(x="timepoint", y="Area",hue="hue", data=df, palette="Set1", order=2, ci=99.7, x_bins=15, x_ci=None, scatter=True)

plt.savefig('CgEcAreaCgEc.png', dpi=300, bbox_inches='tight')
