# %% [markdown]
# # Plotting Phage Concentration Across the Depth of a Biofilm

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


plt.style.use('seaborn-darkgrid')
df= pd.read_csv("P5fig.csv")

mag=(.955,0,.955) 
b=(0.027,.091,.451) 

g=sns.relplot(x="x", y="y", kind="line", style="hue", markers= ["o", "o"], palette=c,hue="hue", data=df)
plt.savefig('pph.png', dpi=300, bbox_inches='tight')
